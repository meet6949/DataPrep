# %% [markdown]
# # 📊 Data Profiler Project
#
# ## 🎯 Objective
# Perform Data Preprocessing, Feature Engineering, and EDA using multiple data sources.

# %% [markdown]
# # 🧠 PART A: FUNDAMENTALS
#
# ## 📌 What is Data Analysis?
# Data Analysis is the process of inspecting, cleaning, transforming, and modeling data to extract useful information and support decision-making.
#
# ## 🚀 Steps in Data Science Project
# 1. Problem Definition
# 2. Data Collection
# 3. Data Cleaning
# 4. Exploratory Data Analysis (EDA)
# 5. Feature Engineering
# 6. Model Building
# 7. Evaluation
# 8. Deployment
#
# ## 🎯 Machine Learning Problem Statement
# Predict outcomes or patterns using historical data.
#
# ## 🔢 What are Tensors?
# Tensors are multi-dimensional arrays used in machine learning.
# - Scalar (0D)
# - Vector (1D)
# - Matrix (2D)
# - Higher dimensions

# %%
import numpy as np
scalar = np.array(25)
vector = np.array([1,2,3])
matrix = np.array([[4,5],[6,7]])
print('Scalar:', scalar)
print('Vector:', vector)
print('Matrix:\n', matrix)
# Out:
# Scalar: 25
# Vector: [1 2 3]
# Matrix:
#  [[4 5]
#  [6 7]]

# %% [markdown]
# # 📥 PART B: DATA ACQUISITION

# %%
import pandas as pd
df_csv = pd.read_csv('ipl_dataset.csv')
df_csv.head()
# Out:
#    match_id team opponent         venue       city toss_winner toss_decision  \
# 0         1  RCB       GT  Eden Gardens  Bangalore          RR           Bat
# 1         2   DC       MI   Chinnaswamy    Chennai          DC           Bat
# 2         3  SRH       RR  Eden Gardens    Kolkata          GT          Bowl
# 3         4  RCB       MI         Kotla    Chennai         KKR           Bat
# 4         5   RR      RCB         Kotla    Chennai         LSG          Bowl
#
#    innings player_name         role  runs  balls_faced  strike_rate  fours  \
# 0        1   Player_54       Bowler    16           13   123.076923      4
# 1        1  Player_317  All-rounder    57           71    80.281690      4
# 2        2  Player_142  All-rounder    49           63    77.777778      4
# 3        1  Player_271  All-rounder    76           88    86.363636      1
# 4        2   Player_64  All-rounder    58           60    96.666667      3
#
# ...

# %%
df_json = pd.read_json('sample.json')
df_json.head()
# Out:
#    match_id                team1                team2               winner  \
# 0         1  Chennai Super Kings       Mumbai Indians       Mumbai Indians
# 1         2     Rajasthan Royals       Mumbai Indians       Mumbai Indians
# 2         3  Chennai Super Kings                  KKR  Chennai Super Kings
# 3         4       Mumbai Indians                  RCB                  RCB
# 4         5     Rajasthan Royals  Chennai Super Kings  Chennai Super Kings
#
#            toss_winner toss_decision                 venue  runs_team1  \
# 0  Chennai Super Kings         field  Arun Jaitley Stadium         171
# 1     Rajasthan Royals           bat      Wankhede Stadium         133
# 2                  KKR           bat          Eden Gardens         193
# 3                  RCB           bat   Chinnaswamy Stadium         125
# 4  Chennai Super Kings         field  Arun Jaitley Stadium         168
#
#    runs_team2
# 0         203
# 1         152
# 2         188
# 3         207
# ...

# %%
import sqlite3
conn = sqlite3.connect('ecommerce.db')
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
tables
# Out:
#      name
# 0  orders

# %%
import requests
import pandas as pd

url = "https://jsonplaceholder.typicode.com/posts"

response = requests.get(url)
data = response.json()[:10]   # ✅ only first 10 records

df_api = pd.DataFrame(data)
df_api.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %% [markdown]
# # 🧹 PART C: DATA CLEANING

# %%
df_csv.info()
df_csv.describe()
df_csv.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4075 entries, 0 to 4074
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   match_id         4075 non-null   int64
#  1   team             4075 non-null   str
#  2   opponent         4075 non-null   str
#  3   venue            4075 non-null   str
#  4   city             4075 non-null   str
#  5   toss_winner      4075 non-null   str
#  6   toss_decision    4075 non-null   str
#  7   innings          4075 non-null   int64
#  8   player_name      4075 non-null   str
#  9   role             4075 non-null   str
#  10  runs             4075 non-null   int64
#  11  balls_faced      4075 non-null   int64
#  12  strike_rate      3802 non-null   float64
#  13  fours            4075 non-null   int64
#  14  sixes            4075 non-null   int64
#  15  wickets          4075 non-null   int64
#  16  overs_bowled     4075 non-null   float64
# ...

# %%
df_csv.ffill(inplace=True)
df_csv.drop_duplicates(inplace=True)
df_csv.head()
# Out:
#    match_id team opponent         venue       city toss_winner toss_decision  \
# 0         1  RCB       GT  Eden Gardens  Bangalore          RR           Bat
# 1         2   DC       MI   Chinnaswamy    Chennai          DC           Bat
# 2         3  SRH       RR  Eden Gardens    Kolkata          GT          Bowl
# 3         4  RCB       MI         Kotla    Chennai         KKR           Bat
# 4         5   RR      RCB         Kotla    Chennai         LSG          Bowl
#
#    innings player_name         role  runs  balls_faced  strike_rate  fours  \
# 0        1   Player_54       Bowler    16           13   123.076923      4
# 1        1  Player_317  All-rounder    57           71    80.281690      4
# 2        2  Player_142  All-rounder    49           63    77.777778      4
# 3        1  Player_271  All-rounder    76           88    86.363636      1
# 4        2   Player_64  All-rounder    58           60    96.666667      3
#
# ...

# %% [markdown]
# # 📊 PART D: EDA

# %%
import matplotlib.pyplot as plt
df_csv['runs'].hist()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='runs', y='strike_rate', data=df_csv)
plt.title("Runs vs Strike Rate")
plt.show()

# %%
corr = df_csv.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# # 📑 PART E: DATA PROFILING

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df_csv, title="CSV Data Profiling Report", explorative=True)
profile.to_file("csv_data_profile_report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2 profile = ProfileReport(df_csv, title="CSV Data Profiling Report", explorative=True)
#       3 profile.to_file("csv_data_profile_report.html")
#
# ModuleNotFoundError: No module named 'ydata_profiling'
